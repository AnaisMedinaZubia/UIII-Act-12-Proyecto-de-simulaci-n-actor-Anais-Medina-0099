# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaisMedinaZubia/UIII-Act-12-Proyecto-de-simulaci-n-actor-Anais-Medina-0099/blob/main/UIII_Act_12_Proyecto_de_simulaci%C3%B3n_actor_Anais_Medina_0099.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Anais Medina NL = 40 fecha 26/05/2026
# #### Lista actor

# %%
# --- SISTEMA DE IA: AGENTE DE CASTING "TALENT-SCAN POO" ---

base_datos_actor = []

class Actor:
    """Clase que define los atributos y comportamiento de un Actor"""

    # === ¡MIRA AQUÍ! TODOS LOS 'def' EMPIEZAN EXACTAMENTE EN LA MISMA LÍNEA ===

    def __init__(self, nombre, agencia, obras, premios, habilidades, edad, proyecto):
        self.nombre = nombre
        self.agencia = agencia
        self.obras = obras
        self.premios = premios
        self.habilidades = habilidades.lower()
        self.edad = edad
        self.proyecto = proyecto

    def evaluar_perfil_ia(self):
        if self.premios >= 3 and self.obras > 15:
            return "CATEGORÍA: ESTRELLA DE ÉLITE (Apto para Proyectos Globales)"
        elif "artes marciales" in self.habilidades or "acrobacia" in self.habilidades:
            return "CATEGORÍA: ESPECIALISTA EN ACCIÓN (Apto para Stunts)"
        elif self.edad < 22 and self.obras <= 3:
            return "CATEGORÍA: NUEVA PROMESA (Apto para Series Juveniles)"
        else:
            return "CATEGORÍA: ACTOR VERSÁTIL (Apto para Elenco de Soporte)"


    def agregar_actor():
        print("\n--- REGISTRO DE TALENTO ---")
        nombre = input("Nombre: ")
        agencia = input("Agencia: ")
        obras = int(input("Obras realizadas: "))
        premios = int(input("Premios ganados: "))
        habilidades = input("Habilidades (ej: Canto, Baile, Esgrima): ")
        edad = int(input("Rango de edad: "))
        proyecto = input("Último proyecto: ")

        nuevo_actor = Actor(nombre, agencia, obras, premios, habilidades, edad, proyecto)
        base_datos_actor.append(nuevo_actor)
        print(f"¡{nombre} registrado con éxito!")


    def listar_actor():
        if len(base_datos_actor) == 0:
            print("\n[!] No hay actores en la base de datos.")
        else:
            header = f"{'NOMBRE':<15} | {'AGENCIA':<15} | {'OBRAS':<6} | {'PREMIOS':<8} | {'EDAD':<5} | {'PROYECTO':<15}"
            print("\n" + "="*85)
            print(header)
            print("-" * 85)

            for a in base_datos_actor:
                print(f"{a.nombre:<15} | {a.agencia:<15} | {a.obras:<6} | {a.premios:<8} | {a.edad:<5} | {a.proyecto:<15}")
            print("="*85)


    def actualizar_actor():
        nombre_buscar = input("\nNombre del actor a actualizar: ")
        encontrado = False
        for a in base_datos_actor:
            if a.nombre == nombre_buscar:
                print(f"Modificando datos de {a.nombre}...")
                a.agencia = input("Nueva Agencia: ")
                a.obras = int(input("Nuevas Obras: "))
                a.premios = int(input("Nuevos Premios: "))
                a.proyecto = input("Nuevo Proyecto: ")
                encontrado = True
                print("Datos actualizados.")
                break
        if not encontrado:
            print("Actor no encontrado.")


    def borrar_actor():
        nombre_borrar = input("\nNombre del actor a eliminar: ")
        for a in base_datos_actor:
            if a.nombre == nombre_borrar:
                base_datos_actor.remove(a)
                print(f"¡{nombre_borrar} eliminado!")
                return
        print("Actor no encontrado.")


    def ejecutar_ia():
        print("\n[IA] Iniciando escaneo de perfiles para Casting...")
        if len(base_datos_actor) == 0:
            print("Sin datos para analizar.")
        else:
            for a in base_datos_actor:
                resultado = a.evaluar_perfil_ia()
                print(f"Actor: {a.nombre} -> {resultado}")


# --- MENÚ PRINCIPAL ---
# Nota cómo ahora llamamos a las funciones usando "Actor.nombre_funcion()"
while True:
    print("\n========================================")
    print("      SISTEMA IA: TALENT-SCAN 3.0      ")
    print("========================================")
    print("1. Agregar Actor")
    print("2. Listar Actores (Tabla)")
    print("3. Actualizar Actor")
    print("4. Borrar Actor")
    print("5. IA: Análisis de Perfiles")
    print("6. Salir")

    opcion = input("\nSeleccione una opción: ")

    if opcion == "1":
        Actor.agregar_actor()
    elif opcion == "2":
        Actor.listar_actor()
    elif opcion == "3":
        Actor.actualizar_actor()
    elif opcion == "4":
        Actor.borrar_actor()
    elif opcion == "5":
        Actor.ejecutar_ia()
    elif opcion == "6":
        print("Apagando sistema... ¡Corte!")
        print("Programa realizado por Anais Medina NL = 40")
        break
    else:
        print("Opción inválida.")
# Out:
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 1
#
# --- REGISTRO DE TALENTO ---
# Nombre: Alicia
# Agencia: disney
# Obras realizadas: 4
# Premios ganados: 3
# Habilidades (ej: Canto, Baile, Esgrima): canto
# Rango de edad: 23
# Último proyecto: Wonderland
# ¡Alicia registrado con éxito!
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 2
#
# =====================================================================================
# NOMBRE          | AGENCIA         | OBRAS  | PREMIOS  | EDAD  | PROYECTO
# -------------------------------------------------------------------------------------
# Alicia          | disney          | 4      | 3        | 23    | Wonderland
# =====================================================================================
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 1
#
# --- REGISTRO DE TALENTO ---
# Nombre: Ariana
# Agencia: disney chanel
# Obras realizadas: 23
# Premios ganados: 19
# Habilidades (ej: Canto, Baile, Esgrima): canto
# Rango de edad: 27
# Último proyecto: yes, and?
# ¡Ariana registrado con éxito!
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 2
#
# =====================================================================================
# NOMBRE          | AGENCIA         | OBRAS  | PREMIOS  | EDAD  | PROYECTO
# -------------------------------------------------------------------------------------
# Alicia          | disney          | 4      | 3        | 23    | Wonderland
# Ariana          | disney chanel   | 23     | 19       | 27    | yes, and?
# =====================================================================================
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 1
#
# --- REGISTRO DE TALENTO ---
# Nombre: the rock
# Agencia: holliwon
# Obras realizadas: 59
# Premios ganados: 13
# Habilidades (ej: Canto, Baile, Esgrima): bailar
# Rango de edad: 46
# Último proyecto: moana
# ¡the rock registrado con éxito!
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 2
#
# =====================================================================================
# NOMBRE          | AGENCIA         | OBRAS  | PREMIOS  | EDAD  | PROYECTO
# -------------------------------------------------------------------------------------
# Alicia          | disney          | 4      | 3        | 23    | Wonderland
# Ariana          | disney chanel   | 23     | 19       | 27    | yes, and?
# the rock        | holliwon        | 59     | 13       | 46    | moana
# =====================================================================================
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 3
#
# Nombre del actor a actualizar: the rock
# Modificando datos de the rock...
# Nueva Agencia: fox
# Nuevas Obras: 67
# Nuevos Premios: 18
# Nuevo Proyecto: jumanji
# Datos actualizados.
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 2
#
# =====================================================================================
# NOMBRE          | AGENCIA         | OBRAS  | PREMIOS  | EDAD  | PROYECTO
# -------------------------------------------------------------------------------------
# Alicia          | disney          | 4      | 3        | 23    | Wonderland
# Ariana          | disney chanel   | 23     | 19       | 27    | yes, and?
# the rock        | fox             | 67     | 18       | 46    | jumanji
# =====================================================================================
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 4
#
# Nombre del actor a eliminar: Alicia
# ¡Alicia eliminado!
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 2
#
# =====================================================================================
# NOMBRE          | AGENCIA         | OBRAS  | PREMIOS  | EDAD  | PROYECTO
# -------------------------------------------------------------------------------------
# Ariana          | disney chanel   | 23     | 19       | 27    | yes, and?
# the rock        | fox             | 67     | 18       | 46    | jumanji
# =====================================================================================
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 5
#
# [IA] Iniciando escaneo de perfiles para Casting...
# Actor: Ariana -> CATEGORÍA: ESTRELLA DE ÉLITE (Apto para Proyectos Globales)
# Actor: the rock -> CATEGORÍA: ESTRELLA DE ÉLITE (Apto para Proyectos Globales)
#
# ========================================
#       SISTEMA IA: TALENT-SCAN 3.0
# ========================================
# 1. Agregar Actor
# 2. Listar Actores (Tabla)
# 3. Actualizar Actor
# 4. Borrar Actor
# 5. IA: Análisis de Perfiles
# 6. Salir
#
# Seleccione una opción: 6
# Apagando sistema... ¡Corte!
# Programa realizado por Anais Medina NL = 40

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/AnaisMedinaZubia/UIII-Act-12-Proyecto-de-simulaci-n-actor-Anais-Medina-0099/refs/heads/main/infografiactores0099.png)
